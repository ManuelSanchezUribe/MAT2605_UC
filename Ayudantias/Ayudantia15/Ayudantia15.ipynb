# %% [markdown]
# <center><h1 style="color:#173F8A;"> Cálculo Científico I, MAT2605, 2025-2 </h1></center>
# <h3 style="color:#173F8A;text-align:left;"> Facultad de Matemáticas<br>  Pontificia Universidad Catolica de Chile <br>  </h3>
# <h3 style="color:#0176DE;text-align:left;"> Profesor: Manuel A. Sanchez<br> </h3>
# <h4 style="color:#0176DE;text-align:left;"> Ayudantes: Tomás Malfetano (tomas.malfetano@uc.cl), Diego Vera (dva@uc.cl)<br> </h4>
# <hr style="border:2px solid #03122E"> </hr>
#
# <!-- Palette colors UC: celeste:#0176DE, azul #173F8A, azul oscuro: #03122E, amarillo: #FEC60D, amarillo oscuro: #E3AE00 -->
# <!--
# <figure>
# <img align ="right" src="IMClogo.png" alt="logo" width="200" height="400"><br><br><br><br><br>
# </figure>
#  -->
# <!-- Palette colors UC:
# Primaria:
# celeste:#0176DE, azul #173F8A, azul oscuro: #03122E, amarillo: #FEC60D, amarillo oscuro: #E3AE00
# Secundaria
# gris oscuro: #707070
# -->

# %% [markdown]
# # Ayudantía 15

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problema 1

# %% [markdown]
# Dados ciertos nodos $\{x_0, ..., x_n\}$ y pesos $\{w_0, ..., w_n\}$ que definen una regla de cuadratura en el intervalo $[a, b]$, decimos que la regla de cuadratura es exacta para polinomios de grado $n$ si se cumple que:
#
# $$\int_a^b p(x)dx = \sum_{k=0}^{n} w_k p(x_k) \quad \forall p \in \mathcal{P}_{n}$$
#
# Demuestre que la regla de cuadratura es exacta para todo polinomio de grado $n$ si y solo si es exacta para los monomios $\{1, x, ..., x^n\}$.

# %% [markdown]
# ## Problema 2

# %% [markdown]
# Considere la regla de cuadratura para aproximar $I(f) = \int_a^bf(x)dx$, definida por:
#
# $$Q(f) = Af\bigg(a+\frac{h}{3}\bigg) + Bf\bigg(b-\frac{h}{4}\bigg)$$
#
# Donde $h=b-a$, y $A$, $B$ son coeficientes constantes.
#
# 1. Para el caso $[a,b] = [0,1]$, demuestre que el grado de exactitud se maximiza con $A=\frac{3}{5}$ y $B=\frac{2}{5}$.
# 2. Determine los valores de $A$ y $B$ para el caso general en $[a,b]$.
# 3. Muestre que $Q$ es una cuadatura interpolatoria. Es decir, es la integral de cierto polinomio interpolante de $f$.

# %% [markdown]
# ## Problema 3

# %% [markdown]
# Considere el problema de aproximar la integral en $D=[a,b]\times[c,d]$ de una función $f : \R^2 \to \R$:
#
# $$\int_D f(x,y)dxdy$$
#
# 1. Escriba una formula para aproximar $F(x) := \int_{c}^{d}f(x,y)dy$ mediante la regla del trapecio compuesta.
# 2. Escriba una formula para aproximar $I(f) := \int_{a}^{b}F(x)dx$ mediante la regla del trapecio compuesta.
# 3. Concluya escribiendo una formula para aproximar la integral en $D$.
# 4. Generalize la formula para dominios de la siguiente forma:
#     $$ \Omega = \{ (x,y) \in \R^2 : a \leq x \leq b, r(x) \leq y \leq s(x)\}$$
